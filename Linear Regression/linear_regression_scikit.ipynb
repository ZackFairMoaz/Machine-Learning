# %% [markdown]
# ### Linear Regression Model Using ScikitLearn

# %%
#Importing Required Libraries and datasets
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, Y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
#Choosing just one feature out of 10
X = X[:, 2] # second feature selected
print(X.shape)
# Out:
# (442,)

# %%
X = X.reshape(-1, 1) # reshaping X to a 2d array with 422 rows and 1 col
print(X.shape)
# Out:
# (442, 1)

# %%
#Spliting training and testing data for x and y
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color= 'red', linewidth='3')
plt.show()
